# %% [markdown]
# # NaiveExactMatching-MatchingRealReads

# %%
# !pip install pytest ipytest -q

# %%
# !wget http://d28rh4a8wq0iu5.cloudfront.net/ads1/data/phix.fa

# %%
def readGenome(filename: str) -> str:
    """ Reads dna data from a given file
    param: filename name of a fasta file
    returns: dna data without the ids of the fasta file
    rtype: string
    """
    # copy from notebook 1.06

    return genome

# %%
genome = readGenome('phix.fa')

# %%
from typing import List

def naive(p: str, t: str) -> List[int]:
    """Implementation of a 'naive' pattern search in text t
    param: p search-pattern
    param: t text to search in
    returns: list of occurences
    """
    # copy from notebook 1.06

    return occurrences

# %%
import random
def generateReads(genome: str, numReads: int, readLen:int) -> List[str]:
    """Generate reads from random positions in the given genome.
    param: genome dna data from which reads should be generated
    param: numReads defines how many different reads are generated
    param: readLen defines the length of each read
    returns: list containing the generated reads
    """
    # copy from notebook 1.06

    return reads

# %%
# Generate 100 reads of length 100
reads = generateReads(genome, 100, 100)

# Count how many reads match the genome exactly
numMatched = 0
for r in reads:
    matches = naive(r, genome)
    if len(matches) > 0:
        numMatched += 1
print(f'{numMatched} / {len(reads)} reads matched the genome exactly!')

# %%
# On Windows you have to manually download the file
# !wget http://d28rh4a8wq0iu5.cloudfront.net/ads1/data/ERR266411_1.first1000.fastq

# %%
def readFastq(filename: str) -> List[str]:
    """ Reads a FastQ File
    param filename: name of the fastq file
    returns: list containing all the dna sequences from the fastq file
    """
    sequences = []

    return sequences

# %%
numMatched = 0
n = 0
for r in phix_reads:
    matches = naive(r, genome)
    n += 1
    if len(matches) > 0:
        numMatched += 1
print(f'{numMatched} / {n} reads matched the genome exactly!')

# %%
# Now let's try matching just the first 30 bases of each read
numMatched = 0
n = 0
for r in phix_reads:
    r = r[:30]  # just taking the first 30 bases
    matches = naive(r, genome)
    n += 1
    if len(matches) > 0:
        numMatched += 1
print(f'{numMatched} / {n} reads matched the genome exactly!')

# %%
def reverseComplement(s: str) -> str:
    complement = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A', 'N': 'N'}
    t = ''
    for base in s:
        t = complement[base] + t
    return t

# %%
numMatched = 0
n = 0
for r in phix_reads:
    r = r[:30]  # just taking the first 30 bases
    matches = naive(r, genome)
    matches.extend(naive(reverseComplement(r), genome))
    n += 1
    if len(matches) > 0:
        numMatched += 1
print(f'{numMatched} / {n} reads matched the genome exactly!')

# %% [markdown]
# ### Compare the different results on the matches!
# Think of the different numbers of matches and why these numbers arise. Make some notes!

# %%
# %ipytest

import ipytest
import pytest

ipytest.autoconfig()

import collections

def test_readGenome(): # changed to a function
    assert len(readGenome('phix.fa')) == 5386, 'length of genome string for file phix.fa is wrong! Correct length should be: 5386'

def test_naive(): # changed to a function
    assert naive('AG','AGCTTAGATAGC') == [0, 5, 9], 'Tested naive with parameters: p="AG" and t="AGCTTAGATAGC". Should return this list of occurences: [0, 5, 9]'

def test_generate_reads(): # changed to a function
    genome = readGenome('phix.fa')
    reads = generateReads(genome, 100, 100)
    assert len(reads) == 100, 'Generated wrong number of reads! Should be 100 is {}'.format(len(reads))
    for read in reads:
        assert len(read) == 100, 'Read has wrong length. Should be 100 is {}'.format(len(read))

def test_readFastq(): # changed to a function
    phix_reads = readFastq('ERR266411_1.first1000.fastq')
    count = collections.Counter()
    for read in phix_reads:
        count.update(read)
    assert count['T'] == 30531, 'Count for T is wrong. Should be 30531 but is {}'.format(count['T'])
    assert count['A'] == 28426, 'Count for A is wrong. Should be 28426 but is {}'.format(count['A'])
    assert count['C'] == 21890, 'Count for C is wrong. Should be 21890 but is {}'.format(count['C'])
    assert count['G'] == 19147, 'Count for G is wrong. Should be 19147 but is {}'.format(count['G'])
    assert count['N'] == 6, 'Count for N is wrong. Should be 6 but is {}'.format(count['N'])
