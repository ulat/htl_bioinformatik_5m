# %%
# !pip install pytest ipytest -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.6 MB/s eta 0:00:00

# %%
# Funktioniert nur unter ix-Betriebssystemen. Unter Windows muss die Datei manuell herunter-
# geladen werden.
# !wget http://d28rh4a8wq0iu5.cloudfront.net/ads1/data/phix.fa
# Out:
# --2025-11-23 08:38:03--  http://d28rh4a8wq0iu5.cloudfront.net/ads1/data/phix.fa
# Resolving d28rh4a8wq0iu5.cloudfront.net (d28rh4a8wq0iu5.cloudfront.net)... 54.240.190.166, 54.240.190.87, 54.240.190.146, ...
# Connecting to d28rh4a8wq0iu5.cloudfront.net (d28rh4a8wq0iu5.cloudfront.net)|54.240.190.166|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5528 (5.4K) [application/octet-stream]
# Saving to: ‘phix.fa’
#
# phix.fa             100%[===================>]   5.40K  --.-KB/s    in 0s
#
# 2025-11-23 08:38:04 (445 MB/s) - ‘phix.fa’ saved [5528/5528]

# %%
def readGenome(filename: str) -> str:
    """ Reads dna data from a given file
    param: filename name of a fasta file
    returns: dna data without the ids of the fasta file
    rtype: string
    """
    genome = ''

    return genome

# %%
from typing import List
def naive(p: str, t: str) -> List[int]:
    """Implementation of a 'naive' pattern search in text t
    param: p search-pattern
    param: t text to search in
    returns: list of occurences
    """
    occurrences = []
    return occurrences

# %%
import random
def generateReads(genome: str, numReads: int, readLen: int) -> List[str]:
    """Generate reads from random positions in the given genome.
    param: genome dna data from which reads should be generated
    param: numReads defines how many different reads are generated
    param: readLen defines the length of each read
    returns: list containing the generated reads
    """
    reads = []

    return reads

# %%
# Generate 100 reads of length 100
reads = generateReads(genome, 100, 100)

# Count how many reads match the genome exactly
numMatched = 0
for r in reads:
    matches = naive(r, genome)
    if len(matches) > 0:
        numMatched += 1
# works, but "old" python style
# print('%d / %d reads matched the genome exactly!' % (numMatched, len(reads)))
# new pythonic way using formatted strings...
print(f'{numMatched} / {len(reads)} reads matched the genome exactly!')
# Out:
# 100 / 100 reads matched the genome exactly!

# %%
# %%ipytest
#
# import ipytest
# import pytest
#
# ipytest.autoconfig()
#
# import pickle as pkl
# with open('1.06_vars.pkl', 'rb') as f:
#     genome  = pkl.load(f)
#
# # Pytest tests
# def test_readGenome():
#     # Assuming readGenome is defined and phix.fa exists
#     assert readGenome('phix.fa') == genome
#
# def test_naive():
#     assert naive('AG','AGCTTAGATAGC') == [0, 5, 9]
#
# def test_generateReads():
#     # Assuming generateReads is defined
#     reads = generateReads(genome, 100, 100)
#     assert len(reads) == 100
#
# def test_numMatched():
#     # Assuming generateReads, naive, and numMatched calculation are defined
#     # This test depends on the previous cell's execution which is not ideal for unit tests.
#     # For a proper unit test, you would mock or pass in the expected reads and genome.
#     # However, based on the original notebook structure, we will keep this dependency for now.
#     assert numMatched == 100
# Out:
# .FFF                                                                                         [100%]
# ============================================= FAILURES =============================================
# ____________________________________________ test_naive ____________________________________________
#
#     def test_naive():
# >       assert naive('AG','AGCTTAGATAGC') == [0, 5, 9]
#                ^^^^^
# E       NameError: name 'naive' is not defined
#
# /tmp/ipython-input-649816102.py:16: NameError
# ________________________________________ test_generateReads ________________________________________
#
#     def test_generateReads():
#         # Assuming generateReads is defined
# >       reads = generateReads(genome, 100, 100)
#                 ^^^^^^^^^^^^^
# E       NameError: name 'generateReads' is not defined
#
# /tmp/ipython-input-649816102.py:20: NameError
# _________________________________________ test_numMatched __________________________________________
#
#     def test_numMatched():
#         # Assuming generateReads, naive, and numMatched calculation are defined
#         # This test depends on the previous cell's execution which is not ideal for unit tests.
#         # For a proper unit test, you would mock or pass in the expected reads and genome.
#         # However, based on the original notebook structure, we will keep this dependency for now.
# >       assert numMatched == 100
#                ^^^^^^^^^^
# E       NameError: name 'numMatched' is not defined
#
# /tmp/ipython-input-649816102.py:28: NameError
# ===================================== short test summary info ======================================
# FAILED t_048bceb282424ef096af45b6d2446826.py::test_naive - NameError: name 'naive' is not defined
# FAILED t_048bceb282424ef096af45b6d2446826.py::test_generateReads - NameError: name 'generateReads' is not defined
# FAILED t_048bceb282424ef096af45b6d2446826.py::test_numMatched - NameError: name 'numMatched' is not defined
# 3 failed, 1 passed in 0.03s
